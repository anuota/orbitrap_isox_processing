# %%
#following 
# https://rpy2.github.io/doc/v2.9.x/html/introduction.html#:~:text=Installing%20packages&text=Downloading%20and%20installing%20R%20packages,features%20is%20provided%20in%20rpy2. 
#pip install rpy2

# %%
from rpy2.robjects.packages import importr
# import R's "base" package
base = importr('base')

# import R's "utils" package
utils = importr('utils')

# %%
# import rpy2's package module
import rpy2.robjects.packages as rpackages

# import R's utility package
utils = rpackages.importr('utils')

# select a mirror for R packages
utils.chooseCRANmirror(ind=1) # select the first mirror in the list
# Out:
# <rpy2.rinterface_lib.sexp.NULLType object at 0x10aad6780> [RTYPES.NILSXP]

# %%
# # R package names
# packnames = ('IRkernel', 'isoorbi')

# # R vector of strings
# from rpy2.robjects.vectors import StrVector

# # Selectively install what needs to be install.
# # We are fancy, just because we can.
# names_to_install = [x for x in packnames if not rpackages.isinstalled(x)]
# if len(names_to_install) > 0:
#     utils.install_packages(StrVector(names_to_install))
# Out:
# R[write to console]: устанавливаю также зависимости ‘bit’, ‘prettyunits’, ‘fastmap’, ‘ellipsis’, ‘fansi’, ‘utf8’, ‘pkgconfig’, ‘withr’, ‘bit64’, ‘progress’, ‘htmltools’, ‘pillar’, ‘base64enc’, ‘cli’, ‘glue’, ‘lifecycle’, ‘purrr’, ‘tibble’, ‘tidyselect’, ‘vctrs’, ‘cpp11’, ‘generics’, ‘R6’, ‘clipr’, ‘hms’, ‘vroom’, ‘tzdb’, ‘stringi’, ‘repr’, ‘evaluate’, ‘IRdisplay’, ‘pbdZMQ’, ‘crayon’, ‘jsonlite’, ‘uuid’, ‘digest’, ‘tidyr’, ‘dplyr’, ‘magrittr’, ‘rlang’, ‘readr’, ‘stringr’
#
#
# R[write to console]: пробую URL 'https://cloud.r-project.org/bin/macosx/big-sur-x86_64/contrib/4.3/bit_4.0.5.tgz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1286954 bytes (1.2 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
from rpy2.robjects.packages.isoorbi import isoorbi
utils = isoorbi("utils")
help_doc = utils.help("help")
help_doc[0]
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from rpy2.robjects.packages.isoorbi import isoorbi
#       2 utils = isoorbi("utils")
#       3 help_doc = utils.help("help")
#
# ModuleNotFoundError: No module named 'rpy2.robjects.packages.isoorbi'; 'rpy2.robjects.packages' is not a package
